# %% [markdown]
# #### Analyzing data on the potentials of rooftop solar energy
# ##### Importing appropriate libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Loading and exploring dataset

# %%
energy_potential = pd.read_csv("accra_rooftop_solarpotential.csv")
solar_energy_potential = energy_potential.set_index('OBJECTID')
solar_energy_potential
# Out:
#                                           uuid   City  Surface_area  \
# OBJECTID
# 1         40ddf442-0a2f-4b4e-b778-cb0a64a14a76  Accra    177.559998
# 2         60684a59-fc95-4142-8c68-c946ede82625  Accra      1.430000
# 3         d54cf5a1-4485-4b68-b947-86d386a0d0ca  Accra    220.389999
# 4         56441ee9-2d47-45cc-9a6b-0bea427b8436  Accra    326.640015
# 5         d509469b-53ad-4d6e-addd-db9e14a21407  Accra    435.869995
# ...                                        ...    ...           ...
# 268943    ebb29c5e-e7dd-4b15-a404-fe75ec8fb414  Accra    116.389999
# 268944    24756e19-4662-4947-b352-c104a625517d  Accra    143.669998
# 268945    a242d54f-d1ea-4e29-b748-08ba8848fbd6  Accra    363.769989
# 268946    08db8bde-3ecc-4f16-8718-24484ae2dce1  Accra    143.350006
# 268947    9f22d3d6-4d8e-4bf6-b28a-04d0ccad1f90  Accra    137.270004
#
#           Potential_installable_area  Peak_installable_capacity  \
# OBJECTID
# 1                         108.410004                  21.030001
# 2                           0.000000                   0.000000
# 3                         115.190002                  22.350000
# 4                         231.919998                  44.990002
# 5                         334.779999                  64.949997
# ...                              ...                        ...
# 268943                     71.449997                  13.860000
# 268944                     79.900002                  15.520000
# 268945                    270.690002                  52.509998
# 268946                     70.830002                  13.740000
# 268947                     81.750000                  15.860000
#
#           Energy_potential_per_year      Assumed_building_type  \
# OBJECTID
# 1                      29085.339844   multi-family residential
# 2                          0.000000   multi-family residential
# 3                      29268.240234   multi-family residential
# 4                      63574.039062   multi-family residential
# 5                      91602.132812   multi-family residential
# ...                             ...                        ...
# 268943                 19003.570312  single family residential
# 268944                 20671.839844  single family residential
# 268945                 73389.726562  single family residential
# 268946                 17386.699219                 commercial
# 268947                 21325.789062  single family residential
#
#           Estimated_tilt  Estimated_building_height  \
# OBJECTID
# 1               9.120000                       2.71
# 2               0.000000                      11.95
# 3              21.690001                       1.59
# 4               3.530000                      24.59
# 5              18.360001                       4.91
# ...                  ...                        ...
# 268943          6.230000                       4.86
# 268944         13.380000                       6.72
# 268945         16.309999                       5.47
# 268946         23.770000                       2.07
# 268947         14.380000                       7.26
#
#           Estimated_capacity_factor               Date_added  Comment  \
# OBJECTID
# 1                       1383.000000  2020-04-06T10:39:14.000      NaN
# 2                               NaN  2020-04-06T10:39:14.000      NaN
# 3                       1309.770020  2020-04-21T08:32:11.000      NaN
# 4                       1413.000000  2020-04-06T10:39:14.000      NaN
# 5                       1410.410034  2020-04-06T10:39:14.000      NaN
# ...                             ...                      ...      ...
# 268943                  1371.000000  2020-04-06T10:39:14.000      NaN
# 268944                  1332.229980  2020-04-06T10:39:14.000      NaN
# 268945                  1397.530029  2020-04-06T10:39:14.000      NaN
# 268946                  1265.349976  2020-04-06T10:39:14.000      NaN
# 268947                  1344.699951  2020-04-06T10:39:14.000      NaN
#
#           Unit_installation_price
# OBJECTID
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# ...                           ...
# 268943                        NaN
# 268944                        NaN
# 268945                        NaN
# 268946                        NaN
# 268947                        NaN
#
# [268947 rows x 13 columns]

# %%
# Display the first few rows of the dataset
solar_energy_potential.head()
# Out:
#                                           uuid   City  Surface_area  \
# OBJECTID
# 1         40ddf442-0a2f-4b4e-b778-cb0a64a14a76  Accra    177.559998
# 2         60684a59-fc95-4142-8c68-c946ede82625  Accra      1.430000
# 3         d54cf5a1-4485-4b68-b947-86d386a0d0ca  Accra    220.389999
# 4         56441ee9-2d47-45cc-9a6b-0bea427b8436  Accra    326.640015
# 5         d509469b-53ad-4d6e-addd-db9e14a21407  Accra    435.869995
#
#           Potential_installable_area  Peak_installable_capacity  \
# OBJECTID
# 1                         108.410004                  21.030001
# 2                           0.000000                   0.000000
# 3                         115.190002                  22.350000
# 4                         231.919998                  44.990002
# 5                         334.779999                  64.949997
#
#           Energy_potential_per_year     Assumed_building_type  Estimated_tilt  \
# OBJECTID
# 1                      29085.339844  multi-family residential        9.120000
# 2                          0.000000  multi-family residential        0.000000
# 3                      29268.240234  multi-family residential       21.690001
# 4                      63574.039062  multi-family residential        3.530000
# 5                      91602.132812  multi-family residential       18.360001
#
#           Estimated_building_height  Estimated_capacity_factor  \
# OBJECTID
# 1                              2.71                1383.000000
# 2                             11.95                        NaN
# 3                              1.59                1309.770020
# 4                             24.59                1413.000000
# 5                              4.91                1410.410034
#
#                        Date_added  Comment  Unit_installation_price
# OBJECTID
# 1         2020-04-06T10:39:14.000      NaN                      NaN
# 2         2020-04-06T10:39:14.000      NaN                      NaN
# 3         2020-04-21T08:32:11.000      NaN                      NaN
# 4         2020-04-06T10:39:14.000      NaN                      NaN
# 5         2020-04-06T10:39:14.000      NaN                      NaN

# %%
# Get information about the dataset
solar_energy_potential.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 268947 entries, 1 to 268947
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   uuid                        268947 non-null  object
#  1   City                        268947 non-null  object
#  2   Surface_area                268947 non-null  float64
#  3   Potential_installable_area  268947 non-null  float64
#  4   Peak_installable_capacity   268947 non-null  float64
#  5   Energy_potential_per_year   268947 non-null  float64
#  6   Assumed_building_type       268947 non-null  object
#  7   Estimated_tilt              268947 non-null  float64
#  8   Estimated_building_height   267955 non-null  float64
#  9   Estimated_capacity_factor   265113 non-null  float64
#  10  Date_added                  268947 non-null  object
#  11  Comment                     0 non-null       float64
#  12  Unit_installation_price     0 non-null       float64
# dtypes: float64(9), object(4)
# memory usage: 28.7+ MB

# %%
# Generate summary statistics
solar_energy_potential.describe()
# Out:
#         Surface_area  Potential_installable_area  Peak_installable_capacity  \
# count  268947.000000               268947.000000              268947.000000
# mean      190.431518                  124.582001                  24.169090
# std       250.562450                  193.890907                  37.612806
# min         0.000000                    0.000000                   0.000000
# 25%        75.330002                   40.560001                   7.870000
# 50%       147.869995                   86.660004                  16.809999
# 75%       245.500000                  170.220001                  33.020000
# max     23692.609375                19225.660156                3729.780029
#
#        Energy_potential_per_year  Estimated_tilt  Estimated_building_height  \
# count               2.689470e+05   268947.000000              267955.000000
# mean                3.340499e+04       12.123828                   4.728874
# std                 5.254645e+04        5.848504                   8.516883
# min                 0.000000e+00        0.000000                 -29.410000
# 25%                 1.080854e+04        7.370000                   2.830000
# 50%                 2.318246e+04       11.710000                   3.620000
# 75%                 4.357297e+04       16.760000                   4.960000
# max                 5.158282e+06       37.349998                 616.230000
#
#        Estimated_capacity_factor  Comment  Unit_installation_price
# count              265113.000000      0.0                      0.0
# mean                 1378.217301      NaN                      NaN
# std                    45.854117      NaN                      NaN
# min                  1117.000000      NaN                      NaN
# 25%                  1349.000000      NaN                      NaN
# 50%                  1383.000000      NaN                      NaN
# 75%                  1413.000000      NaN                      NaN
# max                  1461.000000      NaN                      NaN

# %% [markdown]
# #### Data cleaning

# %%
# Check for missing values
solar_energy_potential.isnull().sum()
# Out:
# uuid                               0
# City                               0
# Surface_area                       0
# Potential_installable_area         0
# Peak_installable_capacity          0
# Energy_potential_per_year          0
# Assumed_building_type              0
# Estimated_tilt                     0
# Estimated_building_height        992
# Estimated_capacity_factor       3834
# Date_added                         0
# Comment                       268947
# Unit_installation_price       268947
# dtype: int64

# %%
# Handle missing values by filling missing values with zeros:
solar_energy_potential['Peak_installable_capacity'].fillna(0, inplace=True)

# %% [markdown]
# #### Data visualization

# %%
# Scatter plot of Surface Area vs. Energy Potential per Year
plt.figure(figsize=(10, 6))
sns.scatterplot(data=solar_energy_potential, x='Surface_area', y='Energy_potential_per_year', hue='Assumed_building_type')
plt.title('Surface Area vs. Energy Potential per Year')
plt.xlabel('Surface Area')
plt.ylabel('Energy Potential per Year')
plt.grid()

plt.show()

# %% [markdown]
# #### Calculating the average energy potential for different building

# %%
# Calculate average energy potential by building type
average_energy_by_type = solar_energy_potential.groupby('Assumed_building_type')['Energy_potential_per_year'].mean()
average_energy_by_type
# Out:
# Assumed_building_type
# commercial                    48153.745112
# industrial                   147318.600539
# multi-family residential      52690.462021
# public                        60348.661913
# single family residential     28823.220264
# Name: Energy_potential_per_year, dtype: float64

# %%
# Create a bar plot of average energy potential by building type
plt.figure(figsize=(12, 6))
sns.barplot(x=average_energy_by_type.index, y=average_energy_by_type.values, palette='viridis')
plt.title('Average Energy Potential by Building Type')
plt.xlabel('Building Type')
plt.ylabel('Average Energy Potential per Year')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y')

plt.show()
